# %% [markdown]
# This is one of 5 custom functions created to run this application.
#
# It focuses on pulling location options for stargazing. It pulls relevant nearby parks by webscraping google search and pulls their hours and address.

# %%
from bs4 import BeautifulSoup
import requests

# %%
def pull_locs(city,state):
    #intialize empty lists for data
    loc_names=[]
    loc_hours=[]
    loc_addy=[]
    loc_urls=[]
    
    #format city and state names and create url
    city= city.replace(' ','+')
    state= state.replace(' ','+')
    url = 'https://www.google.com/maps/search/'+city+'+'+state+'+'+'parks'
    
    #use requests to pull 1st location
    initial_search = requests.get(url)
    soup = BeautifulSoup(initial_search.content, 'html.parser')
    name = 
    hours = 
    addy = 
    new_url = 
    
        #append data to the lists
    loc_names.append(name)
    loc_hours.append(hours)
    loc_addy.append(addy)
    loc_urls.append(new_url)
    
    
    #use requests to pull 2nd location
    initial_search = requests.get(url)
    soup = BeautifulSoup(initial_search.content, 'html.parser')
    name = 
    hours = 
    addy = 
    new_url = 
    
        #append data to the lists
    loc_names.append(name)
    loc_hours.append(hours)
    loc_addy.append(addy)
    loc_urls.append(new_url)


    #use requests to pull 3rd location
    initial_search = requests.get(url)
    soup = BeautifulSoup(initial_search.content, 'html.parser')
    name = 
    hours = 
    addy = 
    new_url = 
    
        #append data to the lists
    loc_names.append(name)
    loc_hours.append(hours)
    loc_addy.append(addy)
    loc_urls.append(new_url)
    

    #use requests to pull 4th location
    initial_search = requests.get(url)
    soup = BeautifulSoup(initial_search.content, 'html.parser')
    name = 
    hours = 
    addy = 
    new_url = 
    
        #append data to the lists
    loc_names.append(name)
    loc_hours.append(hours)
    loc_addy.append(addy)
    loc_urls.append(new_url)
    
    #use requests to pull 5th location
    initial_search = requests.get(url)
    soup = BeautifulSoup(initial_search.content, 'html.parser')
    name = 
    hours = 
    addy = 
    new_url = 
    
        #append data to the lists
    loc_names.append(name)
    loc_hours.append(hours)
    loc_addy.append(addy)
    loc_urls.append(new_url)
    
    data = pd.DataFrame(list(zip(loc_names,loc_hours,loc_addy,loc_urls)),
                       columns = ['location','hours','address','url'])
    
    return data

# %%
city='new haven'
state= 'ct'
city= city.replace(' ','+')
state= state.replace(' ','+')

url = 'https://www.google.com/maps/search/'+city+'+'+state+'+'+'parks'
initial_search = requests.get(url)

# %%
url
# Out:
# 'https://www.google.com/maps/search/new+haven+ct+parks'

# %%
soup=BeautifulSoup(initial_search.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find_all(class_="keynav-mode-off highres screen-mode")
# Out:
# []

# %%
def find_bill_data(pagee):  
    
    
    places = []    
    song_names=[]
    song_data=[]
    artist_names=[]
    peaks=[]
    
    song_list=pagee.find_all(class_="chart-element__information__song text--truncate color--primary")
    for song in song_list:
        song_names.append(song.text)

    artist_list=pagee.find_all(class_="chart-element__information__artist text--truncate color--secondary")
    for artist in artist_list:
        artist_names.append(artist.text)
    
    peak_list=pagee.find_all(class_="chart-element__information__delta__text text--peak")
    for peak in peak_list:
        peaks.append(peak.text[0])
    
    for i in range(len(song_list)):
        song_data.append({'name':song_names[i],'artist':artist_names[i],'peak':peaks[i]})
        
    return song_data

# %%
search_link =
